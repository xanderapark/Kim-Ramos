# %%
#lets bring in pandas
#Lets import NumPy
#Lets import libraries from sklearn
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn import metrics
from sklearn.svm import SVC
from sklearn.cluster import KMeans
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from statsmodels.graphics.mosaicplot import mosaic
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')
# %matplotlib inline

# %%
df96 = pd.read_csv(r"C:\Users\Kim Ramos\Desktop\Engma data\Ray Allen\CSV\RayAllen_1996-97.csv", sep=",")
df96.head()
# Out:
#    Rk  G       Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS        MP  \
# 0   1  1  1 11 1996  21-104  MIL          @  PHI     W (+8)   1  28:00:00
# 1   2  2  2 11 1996  21-105  MIL        NaN  BOS    W (+22)   1     21:00
# 2   3  3  6 11 1996  21-109  MIL        NaN  VAN    W (+16)   1  26:00:00
# 3   4  4  8 11 1996  21-111  MIL          @  MIA    L (-12)   1  29:00:00
# 4   5  5  9 11 1996  21-112  MIL          @  CHH     W (+2)   1  29:00:00
#
#    ...   ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc
# 0  ...     0    2    2    0    3    0    1   4   13   7.4
# 1  ...     1    2    3    2    3    0    1   1   18  17.7
# 2  ...     0    2    2    1    1    0    3   3   20  12.1
# 3  ...     1    1    2    2    0    0    4   2    9   2.2
# 4  ...     0    0    0    0    1    0    0   3    9   3.4
#
# [5 rows x 29 columns]

# %%
df96des=df96[["FG","FT","3P"]]
df96des.describe()
# Out:
#               FG         FT         3P
# count  82.000000  82.000000  82.000000
# mean    4.756098   2.500000   1.426829
# std     2.427013   2.278455   1.122503
# min     0.000000   0.000000   0.000000
# 25%     3.000000   1.000000   1.000000
# 50%     4.500000   2.000000   1.000000
# 75%     6.000000   4.000000   2.000000
# max    14.000000   9.000000   4.000000

# %%
df96.plot(x='FG', y='FT', style='o')  
plt.title('FG vs FT')  
plt.xlabel('FG')  
plt.ylabel('FT')  
plt.show()

# %%
df96.plot(x='FG', y='3P', style='o')  
plt.title('FG vs 3P')  
plt.xlabel('FG')  
plt.ylabel('3P')  
plt.show()

# %%
df96.plot(x='3P', y='FT', style='o')  
plt.title('3P vs FT')  
plt.xlabel('3P')  
plt.ylabel('FT')  
plt.show()

# %%
FG96= df96des.hist(column='FG')
FG96
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1ACE3F60>]],
#       dtype=object)

# %%
FT96= df96des.hist(column='FT')
FT96
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A15A16588>]],
#       dtype=object)

# %%
ThreeP96= df96des.hist(column='3P')
ThreeP96
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1AE031D0>]],
#       dtype=object)

# %%
df97 = pd.read_csv(r"C:\Users\Kim Ramos\Desktop\Engma data\Ray Allen\CSV\RayAllen_1997-98.csv", sep=",")
df97.head()
# Out:
#    Rk  G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS        MP  \
# 0   1  1  31 10 1997  22-103  MIL          @  PHI    W (+15)   1  41:00:00
# 1   2  2   1 11 1997  22-104  MIL        NaN  NJN     L (-4)   1  42:00:00
# 2   3  3   4 11 1997  22-107  MIL        NaN  ORL    W (+34)   1  25:00:00
# 3   4  4   6 11 1997  22-109  MIL        NaN  PHI     W (+7)   1  29:00:00
# 4   5  5   8 11 1997  22-111  MIL        NaN  BOS     W (+9)   1  45:00:00
#
#    ...   ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc
# 0  ...     0    4    4    5    2    1    2   2   29  23.6
# 1  ...     0    4    4    4    2    0    2   6   26  17.5
# 2  ...     2    0    2    0    1    0    0   2   20  11.8
# 3  ...     0    4    4    5    1    0    3   5   16  10.3
# 4  ...     1    2    3    6    4    0    6   2   20  16.3
#
# [5 rows x 29 columns]

# %%
df97des=df97[["FG","FT","3P"]]
df97des.describe()
# Out:
#               FG         FT         3P
# count  82.000000  82.000000  82.000000
# mean    6.865854   4.170732   1.634146
# std     2.599915   2.463586   1.511374
# min     1.000000   0.000000   0.000000
# 25%     5.000000   2.000000   1.000000
# 50%     7.000000   4.000000   1.000000
# 75%     9.000000   5.000000   2.000000
# max    15.000000  13.000000   7.000000

# %%
df97.plot(x='FG', y='FT', style='o')  
plt.title('FG vs FT')  
plt.xlabel('FG')  
plt.ylabel('FT')  
plt.show()

# %%
df97.plot(x='FG', y='3P', style='o')  
plt.title('FG vs 3P')  
plt.xlabel('FG')  
plt.ylabel('3P')  
plt.show()

# %%
df97.plot(x='3P', y='FT', style='o')  
plt.title('3P vs FT')  
plt.xlabel('3P')  
plt.ylabel('FT')  
plt.show()

# %%
FG97= df97des.hist(column='FG')
FG97
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1AF4A860>]],
#       dtype=object)

# %%
FT97= df97des.hist(column='FT')
FT97
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1AF52898>]],
#       dtype=object)

# %%
ThreeP97= df97des.hist(column='3P')
ThreeP97
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1AED1860>]],
#       dtype=object)

# %%
df98 = pd.read_csv(r"C:\Users\Kim Ramos\Desktop\Engma data\Ray Allen\CSV\RayAllen_1998-99.csv", sep=",")
df98.head()
# Out:
#    Rk  G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS        MP  \
# 0   1  1   6 02 1999  23-201  MIL          @  CHH     W (+6)   1  41:00:00
# 1   2  2   9 02 1999  23-204  MIL          @  TOR    W (+14)   1  31:00:00
# 2   3  3  11 02 1999  23-206  MIL        NaN  NJN    W (+20)   1  30:00:00
# 3   4  4  14 02 1999  23-209  MIL          @  ORL     L (-3)   1  32:00:00
# 4   5  5  16 02 1999  23-211  MIL          @  PHI     W (+1)   1  30:00:00
#
#    ...   ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc
# 0  ...     1    2    3    5    1    0    2   1   25  21.7
# 1  ...     0    2    2    3    3    0    1   2   17  15.9
# 2  ...     1    0    1    3    4    1    3   2   19  18.8
# 3  ...     2    4    6    4    0    0    5   0    8   0.9
# 4  ...     1    1    2    2    3    0    2   4    7   4.0
#
# [5 rows x 29 columns]

# %%
df98des=df98[["FG","FT","3P"]]
df98des.describe()
# Out:
#               FG         FT         3P
# count  50.000000  50.000000  50.000000
# mean    6.060000   3.520000   1.480000
# std     2.518584   2.704795   1.054437
# min     0.000000   0.000000   0.000000
# 25%     5.000000   1.250000   1.000000
# 50%     6.000000   3.000000   1.000000
# 75%     8.000000   5.750000   2.000000
# max    11.000000  11.000000   4.000000

# %%
df98.plot(x='FG', y='FT', style='o')  
plt.title('FG vs FT')  
plt.xlabel('FG')  
plt.ylabel('FT')  
plt.show()

# %%
df98.plot(x='FG', y='3P', style='o')  
plt.title('FG vs 3P')  
plt.xlabel('FG')  
plt.ylabel('3P')  
plt.show()

# %%
df98.plot(x='3P', y='FT', style='o')  
plt.title('3P vs FT')  
plt.xlabel('3P')  
plt.ylabel('FT')  
plt.show()

# %%
FG98= df98des.hist(column='FG')
FG98
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1AFFC470>]],
#       dtype=object)

# %%
FT98= df98des.hist(column='FT')
FT98
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1AFFC588>]],
#       dtype=object)

# %%
ThreeP98= df98des.hist(column='3P')
ThreeP98
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1B0A5470>]],
#       dtype=object)

# %%
df99 = pd.read_csv(r"C:\Users\Kim Ramos\Desktop\Engma data\Ray Allen\CSV\RayAllen_1999-00.csv", sep=",")
df99.head()
# Out:
#    Rk  G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS        MP  \
# 0   1  1   2 11 1999  24-105  MIL          @  HOU     W (+5)   1  30:00:00
# 1   2  2   4 11 1999  24-107  MIL          @  ATL    W (+10)   1  35:00:00
# 2   3  3   6 11 1999  24-109  MIL        NaN  DET    W (+10)   1  32:00:00
# 3   4  4   8 11 1999  24-111  MIL          @  NYK    L (-10)   1  43:00:00
# 4   5  5  10 11 1999  24-113  MIL          @  CHH     L (-6)   1  37:00:00
#
#    ...   ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc
# 0  ...     0    4    4    2    1    0    1   3   19  13.4
# 1  ...     2    3    5    2    1    0    0   1   31  23.2
# 2  ...     1    6    7    5    0    1    1   5   26  19.6
# 3  ...     1    3    4    1    1    0    2   2   18   7.2
# 4  ...     1    3    4    2    1    0    1   2   24  16.8
#
# [5 rows x 29 columns]

# %%
df99des=df99[["FG","FT","3P"]]
df99des.describe()
# Out:
#               FG         FT         3P
# count  82.000000  82.000000  82.000000
# mean    7.829268   4.304878   2.097561
# std     2.628452   2.813938   1.348156
# min     2.000000   0.000000   0.000000
# 25%     6.000000   2.000000   1.000000
# 50%     8.000000   4.000000   2.000000
# 75%    10.000000   6.000000   3.000000
# max    15.000000  11.000000   6.000000

# %%
df99.plot(x='FG', y='FT', style='o')  
plt.title('FG vs FT')  
plt.xlabel('FG')  
plt.ylabel('FT')  
plt.show()

# %%
df99.plot(x='FG', y='3P', style='o')  
plt.title('FG vs 3P')  
plt.xlabel('FG')  
plt.ylabel('3P')  
plt.show()

# %%
df99.plot(x='3P', y='FT', style='o')  
plt.title('3P vs FT')  
plt.xlabel('3P')  
plt.ylabel('FT')  
plt.show()

# %%
FG99= df99des.hist(column='FG')
FG99
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1B28A2E8>]],
#       dtype=object)

# %%
FT99= df99des.hist(column='FT')
FT99
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1B229780>]],
#       dtype=object)

# %%
ThreeP99= df99des.hist(column='3P')
ThreeP99
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1B232CC0>]],
#       dtype=object)

# %%
df00 = pd.read_csv(r"C:\Users\Kim Ramos\Desktop\Engma data\Ray Allen\CSV\RayAllen_2000-01.csv", sep=",")
df00.head()
# Out:
#    Rk  G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS        MP  \
# 0   1  1  31 10 2000  25-103  MIL          @  DAL     L (-4)   1  40:00:00
# 1   2  2   2 11 2000  25-105  MIL          @  HOU    L (-22)   1  33:00:00
# 2   3  3   4 11 2000  25-107  MIL        NaN  DET     W (+9)   1  30:00:00
# 3   4  4   7 11 2000  25-110  MIL        NaN  NYK    L (-14)   1  37:00:00
# 4   5  5   8 11 2000  25-111  MIL          @  IND    L (-11)   1  39:00:00
#
#   ...   DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc  +/-
# 0 ...     2    4    2    0    0    1   1   26  19.3   -9
# 1 ...     4    6    1    1    1    1   6   19  10.3  -10
# 2 ...     4    5    6    3    1    1   4   12  10.2   -4
# 3 ...     6    7    5    0    0    1   4   20  13.6  -15
# 4 ...     3    5    1    0    0    2   3   17   8.0  -12
#
# [5 rows x 30 columns]

# %%
df00des=df00[["FG","FT","3P"]]
df00des.describe()
# Out:
#               FG         FT         3P
# count  82.000000  82.000000  82.000000
# mean    7.658537   4.243902   2.463415
# std     2.978190   3.249163   1.500577
# min     1.000000   0.000000   0.000000
# 25%     6.000000   2.000000   2.000000
# 50%     7.000000   4.000000   2.000000
# 75%     9.000000   6.000000   3.000000
# max    17.000000  19.000000   8.000000

# %%
df00.plot(x='FG', y='FT', style='o')  
plt.title('FG vs FT')  
plt.xlabel('FG')  
plt.ylabel('FT')  
plt.show()

# %%
df00.plot(x='FG', y='3P', style='o')  
plt.title('FG vs 3P')  
plt.xlabel('FG')  
plt.ylabel('3P')  
plt.show()

# %%
df00.plot(x='3P', y='FT', style='o')  
plt.title('3P vs FT')  
plt.xlabel('3P')  
plt.ylabel('FT')  
plt.show()

# %%
FG00= df00des.hist(column='FG')
FG00
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1B2D4B38>]],
#       dtype=object)

# %%
FT00= df00des.hist(column='FT')
FT00
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1B33DE10>]],
#       dtype=object)

# %%
ThreeP00= df00des.hist(column='3P')
ThreeP00
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1C3B09E8>]],
#       dtype=object)

# %%
df01 = pd.read_csv(r"C:\Users\Kim Ramos\Desktop\Engma data\Ray Allen\CSV\RayAllen_2000-01.csv", sep=",")
df01.head()
# Out:
#    Rk  G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS        MP  \
# 0   1  1  31 10 2000  25-103  MIL          @  DAL     L (-4)   1  40:00:00
# 1   2  2   2 11 2000  25-105  MIL          @  HOU    L (-22)   1  33:00:00
# 2   3  3   4 11 2000  25-107  MIL        NaN  DET     W (+9)   1  30:00:00
# 3   4  4   7 11 2000  25-110  MIL        NaN  NYK    L (-14)   1  37:00:00
# 4   5  5   8 11 2000  25-111  MIL          @  IND    L (-11)   1  39:00:00
#
#   ...   DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc  +/-
# 0 ...     2    4    2    0    0    1   1   26  19.3   -9
# 1 ...     4    6    1    1    1    1   6   19  10.3  -10
# 2 ...     4    5    6    3    1    1   4   12  10.2   -4
# 3 ...     6    7    5    0    0    1   4   20  13.6  -15
# 4 ...     3    5    1    0    0    2   3   17   8.0  -12
#
# [5 rows x 30 columns]

# %%
df01des=df01[["FG","FT","3P"]]
df01des.describe()
# Out:
#               FG         FT         3P
# count  82.000000  82.000000  82.000000
# mean    7.658537   4.243902   2.463415
# std     2.978190   3.249163   1.500577
# min     1.000000   0.000000   0.000000
# 25%     6.000000   2.000000   2.000000
# 50%     7.000000   4.000000   2.000000
# 75%     9.000000   6.000000   3.000000
# max    17.000000  19.000000   8.000000

# %%
df01.plot(x='FG', y='FT', style='o')  
plt.title('FG vs FT')  
plt.xlabel('FG')  
plt.ylabel('FT')  
plt.show()

# %%
df01.plot(x='FG', y='3P', style='o')  
plt.title('FG vs 3P')  
plt.xlabel('FG')  
plt.ylabel('3P')  
plt.show()

# %%
df01.plot(x='3P', y='FT', style='o')  
plt.title('3P vs FT')  
plt.xlabel('3P')  
plt.ylabel('FT')  
plt.show()

# %%
FG01= df01des.hist(column='FG')
FG01
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1C572F28>]],
#       dtype=object)

# %%
FT01= df01des.hist(column='FT')
FT01
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1C441438>]],
#       dtype=object)

# %%
ThreeP01= df01des.hist(column='3P')
ThreeP01
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1C5DFC18>]],
#       dtype=object)

# %%
df02a = pd.read_csv(r"C:\Users\Kim Ramos\Desktop\Engma data\Ray Allen\CSV\RayAllen_2002-03a.csv", sep=",")
df02a.head()
# Out:
#    Rk  G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS        MP  \
# 0   1  1  30 10 2002  27-102  MIL          @  PHI     L (-2)   1  34:00:00
# 1   2  2   2 11 2002  27-105  MIL        NaN  ORL    L (-10)   1  32:00:00
# 2   3  3   4 11 2002  27-107  MIL          @  NYK     W (+9)   1  33:00:00
# 3   4  4   6 11 2002  27-109  MIL        NaN  NJN     W (+6)   1  34:00:00
# 4   5  5   7 11 2002  27-110  MIL          @  MIN     L (-4)   1  39:00:00
#
#   ...   DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc  +/-
# 0 ...     1    1    2    0    0    5   5   28  13.0   -7
# 1 ...     2    4    2    1    0    3   2   10   3.4  -14
# 2 ...     7    7    4    1    0    4   4   17   9.5    8
# 3 ...     3    5    3    1    0    2   1   29  21.0    0
# 4 ...     4    5    1    3    0    0   4   27  18.6    1
#
# [5 rows x 30 columns]

# %%
df02ades=df02a[["FG","FT","3P"]]
df02ades.describe()
# Out:
#               FG         FT         3P
# count  76.000000  76.000000  76.000000
# mean    7.868421   4.157895   2.644737
# std     2.699838   2.805008   1.702578
# min     1.000000   0.000000   0.000000
# 25%     6.000000   2.000000   2.000000
# 50%     8.000000   4.000000   2.000000
# 75%    10.000000   6.000000   4.000000
# max    14.000000  11.000000   7.000000

# %%
df02a.plot(x='FG', y='FT', style='o')  
plt.title('FG vs FT')  
plt.xlabel('FG')  
plt.ylabel('FT')  
plt.show()

# %%
df02a.plot(x='FG', y='3P', style='o')  
plt.title('FG vs 3P')  
plt.xlabel('FG')  
plt.ylabel('3P')  
plt.show()

# %%
df02a.plot(x='3P', y='FT', style='o')  
plt.title('3P vs FT')  
plt.xlabel('3P')  
plt.ylabel('FT')  
plt.show()

# %%
FG02= df02ades.hist(column='FG')
FG02
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1B1E9358>]],
#       dtype=object)

# %%
FT02= df02ades.hist(column='FT')
FT02
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1C4D3A90>]],
#       dtype=object)

# %%
ThreeP02= df02ades.hist(column='3P')
ThreeP02
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1C4C2DA0>]],
#       dtype=object)

# %%
df02b = pd.read_csv(r"C:\Users\Kim Ramos\Desktop\Engma data\Ray Allen\CSV\RayAllen_2002-03b.csv", sep=",")
df02b.head()
# Out:
#    Rk  G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS        MP  \
# 0   1  1  30 10 2002  27-102  MIL          @  PHI     L (-2)   1  34:00:00
# 1   2  2   2 11 2002  27-105  MIL        NaN  ORL    L (-10)   1  32:00:00
# 2   3  3   4 11 2002  27-107  MIL          @  NYK     W (+9)   1  33:00:00
# 3   4  4   6 11 2002  27-109  MIL        NaN  NJN     W (+6)   1  34:00:00
# 4   5  5   7 11 2002  27-110  MIL          @  MIN     L (-4)   1  39:00:00
#
#   ...   DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc  +/-
# 0 ...     1    1    2    0    0    5   5   28  13.0   -7
# 1 ...     2    4    2    1    0    3   2   10   3.4  -14
# 2 ...     7    7    4    1    0    4   4   17   9.5    8
# 3 ...     3    5    3    1    0    2   1   29  21.0    0
# 4 ...     4    5    1    3    0    0   4   27  18.6    1
#
# [5 rows x 30 columns]

# %%
df02bdes=df02b[["FG","FT","3P"]]
df02bdes.describe()
# Out:
#               FG         FT         3P
# count  76.000000  76.000000  76.000000
# mean    7.868421   4.157895   2.644737
# std     2.699838   2.805008   1.702578
# min     1.000000   0.000000   0.000000
# 25%     6.000000   2.000000   2.000000
# 50%     8.000000   4.000000   2.000000
# 75%    10.000000   6.000000   4.000000
# max    14.000000  11.000000   7.000000

# %%
df02b.plot(x='FG', y='FT', style='o')  
plt.title('FG vs FT')  
plt.xlabel('FG')  
plt.ylabel('FT')  
plt.show()

# %%
df02b.plot(x='FG', y='3P', style='o')  
plt.title('FG vs 3P')  
plt.xlabel('FG')  
plt.ylabel('3P')  
plt.show()

# %%
df02b.plot(x='3P', y='FT', style='o')  
plt.title('3P vs FT')  
plt.xlabel('3P')  
plt.ylabel('FT')  
plt.show()

# %%
FG02= df02bdes.hist(column='FG')
FG02
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1C82EF98>]],
#       dtype=object)

# %%
FT02= df02bdes.hist(column='FT')
FT02
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1C7D8748>]],
#       dtype=object)

# %%
ThreeP02= df02bdes.hist(column='3P')
ThreeP02
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1C8FC438>]],
#       dtype=object)

# %%
df02c = pd.read_csv(r"C:\Users\Kim Ramos\Desktop\Engma data\Ray Allen\CSV\RayAllen_2002-03c.csv", sep=",")
df02c.head()
# Out:
#    Rk  G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS        MP  \
# 0   1  1  30 10 2002  27-102  MIL          @  PHI     L (-2)   1  34:00:00
# 1   2  2   2 11 2002  27-105  MIL        NaN  ORL    L (-10)   1  32:00:00
# 2   3  3   4 11 2002  27-107  MIL          @  NYK     W (+9)   1  33:00:00
# 3   4  4   6 11 2002  27-109  MIL        NaN  NJN     W (+6)   1  34:00:00
# 4   5  5   7 11 2002  27-110  MIL          @  MIN     L (-4)   1  39:00:00
#
#   ...   DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc  +/-
# 0 ...     1    1    2    0    0    5   5   28  13.0   -7
# 1 ...     2    4    2    1    0    3   2   10   3.4  -14
# 2 ...     7    7    4    1    0    4   4   17   9.5    8
# 3 ...     3    5    3    1    0    2   1   29  21.0    0
# 4 ...     4    5    1    3    0    0   4   27  18.6    1
#
# [5 rows x 30 columns]

# %%
df02cdes=df02c[["FG","FT","3P"]]
df02cdes.describe()
# Out:
#               FG         FT         3P
# count  76.000000  76.000000  76.000000
# mean    7.868421   4.157895   2.644737
# std     2.699838   2.805008   1.702578
# min     1.000000   0.000000   0.000000
# 25%     6.000000   2.000000   2.000000
# 50%     8.000000   4.000000   2.000000
# 75%    10.000000   6.000000   4.000000
# max    14.000000  11.000000   7.000000

# %%
df02c.plot(x='FG', y='FT', style='o')  
plt.title('FG vs FT')  
plt.xlabel('FG')  
plt.ylabel('FT')  
plt.show()

# %%
df02c.plot(x='FG', y='3P', style='o')  
plt.title('FG vs 3P')  
plt.xlabel('FG')  
plt.ylabel('3P')  
plt.show()

# %%
df02c.plot(x='3P', y='FT', style='o')  
plt.title('3P vs FT')  
plt.xlabel('3P')  
plt.ylabel('FT')  
plt.show()

# %%
FG02= df02cdes.hist(column='FG')
FG02
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1C7BABA8>]],
#       dtype=object)

# %%
FT02= df02cdes.hist(column='FT')
FT02
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1B263278>]],
#       dtype=object)

# %%
ThreeP02= df02cdes.hist(column='3P')
ThreeP02
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1B1B2748>]],
#       dtype=object)

# %%
df03 = pd.read_csv(r"C:\Users\Kim Ramos\Desktop\Engma data\Ray Allen\CSV\RayAllen_2003-04.csv", sep=",")
df03.head()
# Out:
#    Rk  G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS        MP  \
# 0   1  1  23 12 2003  28-156  SEA        NaN  PHO    W (+26)   1     23:00
# 1   2  2  27 12 2003  28-160  SEA        NaN  MIN    L (-18)   1  35:00:00
# 2   3  3  29 12 2003  28-162  SEA          @  HOU     W (+1)   1  38:00:00
# 3   4  4  30 12 2003  28-163  SEA          @  MEM     W (+6)   1  30:00:00
# 4   5  5   2 01 2004  28-166  SEA        NaN  LAL     W (+2)   1  39:00:00
#
#   ...   DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc  +/-
# 0 ...     1    2    7    0    0    0   0   24  23.2   22
# 1 ...     7    7    3    0    1    4   1   15   2.1  -19
# 2 ...     6    8    3    1    0    2   0   28  20.8    8
# 3 ...     3    6    4    2    0    5   3   22  13.5    2
# 4 ...     0    0    9    3    0    3   3   35  29.9    1
#
# [5 rows x 30 columns]

# %%
df03des=df03[["FG","FT","3P"]]
df03des.describe()
# Out:
#               FG         FT         3P
# count  56.000000  56.000000  56.000000
# mean    7.982143   4.375000   2.642857
# std     2.773190   2.914306   1.530639
# min     2.000000   0.000000   0.000000
# 25%     6.000000   2.000000   2.000000
# 50%     8.000000   4.000000   2.000000
# 75%     9.000000   6.250000   3.250000
# max    16.000000  12.000000   6.000000

# %%
df03.plot(x='FG', y='FT', style='o')  
plt.title('FG vs FT')  
plt.xlabel('FG')  
plt.ylabel('FT')  
plt.show()

# %%
df03.plot(x='FG', y='3P', style='o')  
plt.title('FG vs 3P')  
plt.xlabel('FG')  
plt.ylabel('3P')  
plt.show()

# %%
df03.plot(x='3P', y='FT', style='o')  
plt.title('3P vs FT')  
plt.xlabel('3P')  
plt.ylabel('FT')  
plt.show()

# %%
FG03= df03des.hist(column='FG')
FG03
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1C745EB8>]],
#       dtype=object)

# %%
FT03= df03des.hist(column='FT')
FT03
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1B193198>]],
#       dtype=object)

# %%
ThreeP03= df03des.hist(column='3P')
ThreeP03
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1CB82828>]],
#       dtype=object)

# %%
df04 = pd.read_csv(r"C:\Users\Kim Ramos\Desktop\Engma data\Ray Allen\CSV\RayAllen_2004-05.csv", sep=",")
df04.head()
# Out:
#    Rk  G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS        MP  \
# 0   1  1   3 11 2004  29-106  SEA          @  LAC    L (-30)   1  38:00:00
# 1   2  2   5 11 2004  29-108  SEA        NaN  ATL    W (+21)   1  38:00:00
# 2   3  3   7 11 2004  29-110  SEA        NaN  SAS    W (+19)   1  39:00:00
# 3   4  4   9 11 2004  29-112  SEA          @  DEN    W (+20)   1  40:00:00
# 4   5  5  10 11 2004  29-113  SEA        NaN  SAC    W (+30)   1  37:00:00
#
#   ...   DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc  +/-
# 0 ...     3    5    5    1    0    3   2   20  13.2  -18
# 1 ...     1    1    3    2    0    4   2   25  17.4   19
# 2 ...     4    6    1    2    0    0   1   24  18.9   22
# 3 ...     5    7    3    1    0    1   1   30  26.4   17
# 4 ...     5    5    5    0    0    3   5   20   9.4   23
#
# [5 rows x 30 columns]

# %%
df04des=df04[["FG","FT","3P"]]
df04des.describe()
# Out:
#               FG         FT         3P
# count  78.000000  78.000000  78.000000
# mean    8.205128   4.846154   2.679487
# std     2.746232   3.361651   1.655323
# min     2.000000   0.000000   0.000000
# 25%     6.000000   2.000000   1.250000
# 50%     8.000000   4.500000   2.000000
# 75%    10.000000   7.000000   4.000000
# max    15.000000  17.000000   7.000000

# %%
df04.plot(x='FG', y='FT', style='o')  
plt.title('FG vs FT')  
plt.xlabel('FG')  
plt.ylabel('FT')  
plt.show()

# %%
df04.plot(x='FG', y='3P', style='o')  
plt.title('FG vs 3P')  
plt.xlabel('FG')  
plt.ylabel('3P')  
plt.show()

# %%
df04.plot(x='3P', y='FT', style='o')  
plt.title('3P vs FT')  
plt.xlabel('3P')  
plt.ylabel('FT')  
plt.show()

# %%
FG04= df04des.hist(column='FG')
FG04
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1CCE4908>]],
#       dtype=object)

# %%
FT04= df04des.hist(column='FT')
FT04
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1CDE7550>]],
#       dtype=object)

# %%
ThreeP04= df04des.hist(column='3P')
ThreeP04
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1DE34DD8>]],
#       dtype=object)

# %%
df05 = pd.read_csv(r"C:\Users\Kim Ramos\Desktop\Engma data\Ray Allen\CSV\RayAllen_2005-06.csv", sep=",")
df05.head()
# Out:
#    Rk  G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS        MP  \
# 0   1  1   2 11 2005  30-105  SEA        NaN  LAC     L (-8)   1  40:21:00
# 1   2  2   4 11 2005  30-107  SEA        NaN  MIN     W (+5)   1  47:38:00
# 2   3  3   8 11 2005  30-111  SEA          @  MEM    L (-25)   1  32:52:00
# 3   4  4   9 11 2005  30-112  SEA          @  CLE    L (-27)   1  35:59:00
# 4   5  5  11 11 2005  30-114  SEA          @  WAS    L (-41)   1  33:55:00
#
#   ...   DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc  +/-
# 0 ...     3    3    1    2    0    2   2   31  21.1   -3
# 1 ...     5    8    4    3    0    4   1   32  21.0   11
# 2 ...     2    3    5    3    0    2   2   15  11.9    1
# 3 ...     1    1    7    1    0    3   0   28  23.2  -14
# 4 ...     2    2    2    2    0    3   1   17   9.4  -21
#
# [5 rows x 30 columns]

# %%
df05des=df05[["FG","FT","3P"]]
df05des.describe()
# Out:
#               FG         FT         3P
# count  78.000000  78.000000  78.000000
# mean    8.730769   4.153846   3.448718
# std     2.867974   2.623950   1.806535
# min     0.000000   0.000000   0.000000
# 25%     7.000000   2.000000   2.000000
# 50%     9.000000   4.000000   4.000000
# 75%    11.000000   6.000000   4.000000
# max    14.000000  12.000000   8.000000

# %%
df05.plot(x='FG', y='FT', style='o')  
plt.title('FG vs FT')  
plt.xlabel('FG')  
plt.ylabel('FT')  
plt.show()

# %%
df05.plot(x='FG', y='3P', style='o')  
plt.title('FG vs 3P')  
plt.xlabel('FG')  
plt.ylabel('3P')  
plt.show()

# %%
df05.plot(x='3P', y='FT', style='o')  
plt.title('3P vs FT')  
plt.xlabel('3P')  
plt.ylabel('FT')  
plt.show()

# %%
FG05= df05des.hist(column='FG')
FG05
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1C74DF98>]],
#       dtype=object)

# %%
FT05= df05des.hist(column='FT')
FT05
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1CCE42E8>]],
#       dtype=object)

# %%
ThreeP05= df05des.hist(column='3P')
ThreeP05
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1CA23438>]],
#       dtype=object)

# %%
df06 = pd.read_csv(r"C:\Users\Kim Ramos\Desktop\Engma data\Ray Allen\CSV\RayAllen_2006-07.csv", sep=",")
df06.head()
# Out:
#    Rk  G       Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS        MP  \
# 0   1  1  1 11 2006  31-104  SEA        NaN  POR     L (-4)   1  38:32:00
# 1   2  2  3 11 2006  31-106  SEA          @  LAL     L (-6)   1  41:10:00
# 2   3  3  5 11 2006  31-108  SEA        NaN  LAL    W (+16)   1  35:59:00
# 3   4  4  7 11 2006  31-110  SEA          @  MIA     L (-3)   1  38:01:00
# 4   5  5  8 11 2006  31-111  SEA          @  ORL     L (-1)   1  42:03:00
#
#   ...   DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc  +/-
# 0 ...     0    1    3    1    0    1   0   22  14.4    3
# 1 ...     4    5    5    6    0    3   4   30  24.0   -2
# 2 ...     1    3    6    1    1    3   3   32  28.2   10
# 3 ...     1    4    3    1    1    4   1   18   9.1   -8
# 4 ...     2    4    3    1    0    0   2   21  17.6   -8
#
# [5 rows x 30 columns]

# %%
df06des=df06[["FG","FT","3P"]]
df06des.describe()
# Out:
#               FG         FT         3P
# count  55.000000  55.000000  55.000000
# mean    9.181818   5.072727   3.000000
# std     3.109668   3.035924   1.710534
# min     3.000000   0.000000   0.000000
# 25%     7.000000   3.000000   2.000000
# 50%     9.000000   4.000000   3.000000
# 75%    11.000000   7.000000   4.000000
# max    17.000000  13.000000   8.000000

# %%
df06.plot(x='FG', y='FT', style='o')  
plt.title('FG vs FT')  
plt.xlabel('FG')  
plt.ylabel('FT')  
plt.show()

# %%
df06.plot(x='FG', y='3P', style='o')  
plt.title('FG vs 3P')  
plt.xlabel('FG')  
plt.ylabel('3P')  
plt.show()

# %%
df06.plot(x='3P', y='FT', style='o')  
plt.title('3P vs FT')  
plt.xlabel('3P')  
plt.ylabel('FT')  
plt.show()

# %%
FG06= df06des.hist(column='FG')
FG06
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1DF5FE10>]],
#       dtype=object)

# %%
FT06= df06des.hist(column='FT')
FT06
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1DEA1B38>]],
#       dtype=object)

# %%
ThreeP06= df06des.hist(column='3P')
ThreeP06
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1E06DA58>]],
#       dtype=object)

# %%
df07 = pd.read_csv(r"C:\Users\Kim Ramos\Desktop\Engma data\Ray Allen\CSV\RayAllen_2007-08.csv", sep=",")
df07.head()
# Out:
#    Rk  G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS        MP  \
# 0   1  1   2 11 2007  32-105  BOS        NaN  WAS    W (+20)   1  38:08:00
# 1   2  2   4 11 2007  32-107  BOS          @  TOR     W (+3)   1  49:10:00
# 2   3  3   7 11 2007  32-110  BOS        NaN  DEN    W (+26)   1  32:48:00
# 3   4  4   9 11 2007  32-112  BOS        NaN  ATL    W (+23)   1  35:14:00
# 4   5  5  10 11 2007  32-113  BOS          @  NJN    W (+11)   1  48:00:00
#
#   ...   DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc  +/-
# 0 ...     2    4    2    0    0    0   2   17  14.6   16
# 1 ...     4    4    0    0    0    2   1   33  25.0   -1
# 2 ...     1    3    6    2    0    2   1   22  22.3   25
# 3 ...     1    2    3    1    0    1   3   14  11.6   14
# 4 ...     8   10    5    0    0    3   1   27  21.4   11
#
# [5 rows x 30 columns]

# %%
df07des=df07[["FG","FT","3P"]]
df07des.describe()
# Out:
#               FG         FT         3P
# count  73.000000  73.000000  73.000000
# mean    6.013699   2.945205   2.465753
# std     2.446614   2.302718   1.444166
# min     0.000000   0.000000   0.000000
# 25%     4.000000   1.000000   1.000000
# 50%     6.000000   3.000000   2.000000
# 75%     7.000000   4.000000   3.000000
# max    12.000000  10.000000   7.000000

# %%
df07.plot(x='FG', y='FT', style='o')  
plt.title('FG vs FT')  
plt.xlabel('FG')  
plt.ylabel('FT')  
plt.show()

# %%
df07.plot(x='FG', y='3P', style='o')  
plt.title('FG vs 3P')  
plt.xlabel('FG')  
plt.ylabel('3P')  
plt.show()

# %%
df07.plot(x='3P', y='FT', style='o')  
plt.title('3P vs FT')  
plt.xlabel('3P')  
plt.ylabel('FT')  
plt.show()

# %%
FG07= df07des.hist(column='FG')
FG07
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1E20B7B8>]],
#       dtype=object)

# %%
FT07= df07des.hist(column='FT')
FT07
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1E2A7DA0>]],
#       dtype=object)

# %%
ThreeP07= df07des.hist(column='3P')
ThreeP07
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1E103F60>]],
#       dtype=object)

# %%
df08 = pd.read_csv(r"C:\Users\Kim Ramos\Desktop\Engma data\Ray Allen\CSV\RayAllen_2008-09.csv", sep=",")
df08.head()
# Out:
#    Rk  G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS        MP  \
# 0   1  1  28 10 2008  33-100  BOS        NaN  CLE     W (+5)   1  40:39:00
# 1   2  2  31 10 2008  33-103  BOS        NaN  CHI    W (+16)   1  28:27:00
# 2   3  3   1 11 2008  33-104  BOS          @  IND    L (-16)   1  26:18:00
# 3   4  4   4 11 2008  33-107  BOS          @  HOU     W (+4)   1  35:06:00
# 4   5  5   5 11 2008  33-108  BOS          @  OKC    W (+13)   1  38:05:00
#
#   ...   DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc  +/-
# 0 ...     3    4    1    1    0    4   1    8   1.0   -1
# 1 ...     1    1    0    0    0    2   0   14   6.6   16
# 2 ...     2    6    1    1    0    4   1   10   4.9  -21
# 3 ...     3    5    5    0    0    2   6   29  24.3   -2
# 4 ...     7    9    4    2    0    2   2   18  14.0    2
#
# [5 rows x 30 columns]

# %%
df08des=df08[["FG","FT","3P"]]
df08des.describe()
# Out:
#               FG         FT         3P
# count  79.000000  79.000000  79.000000
# mean    6.316456   3.000000   2.518987
# std     2.734135   2.275849   1.767664
# min     0.000000   0.000000   0.000000
# 25%     4.000000   1.000000   1.000000
# 50%     6.000000   3.000000   2.000000
# 75%     8.000000   4.000000   3.500000
# max    13.000000   9.000000   8.000000

# %%
df08.plot(x='FG', y='FT', style='o')  
plt.title('FG vs FT')  
plt.xlabel('FG')  
plt.ylabel('FT')  
plt.show()

# %%
df08.plot(x='FG', y='3P', style='o')  
plt.title('FG vs 3P')  
plt.xlabel('FG')  
plt.ylabel('3P')  
plt.show()

# %%
df08.plot(x='3P', y='FT', style='o')  
plt.title('3P vs FT')  
plt.xlabel('3P')  
plt.ylabel('FT')  
plt.show()

# %%
FG08= df08des.hist(column='FG')
FG08
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1DF0B240>]],
#       dtype=object)

# %%
FT08= df08des.hist(column='FT')
FT08
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1CA9A7F0>]],
#       dtype=object)

# %%
ThreeP08= df08des.hist(column='3P')
ThreeP08
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1CCB2B70>]],
#       dtype=object)

# %%
df09 = pd.read_csv(r"C:\Users\Kim Ramos\Desktop\Engma data\Ray Allen\CSV\RayAllen_2009-10.csv", sep=",")
df09.head()
# Out:
#    Rk  G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS        MP  \
# 0   1  1  27 10 2009  34-099  BOS          @  CLE     W (+6)   1  42:21:00
# 1   2  2  28 10 2009  34-100  BOS        NaN  CHA    W (+33)   1  38:01:00
# 2   3  3  30 10 2009  34-102  BOS        NaN  CHI    W (+28)   1     23:17
# 3   4  4   1 11 2009  34-104  BOS        NaN  NOH    W (+10)   1  40:35:00
# 4   5  5   3 11 2009  34-106  BOS          @  PHI    W (+31)   1  30:53:00
#
#   ...   DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc  +/-
# 0 ...     2    2    3    3    0    3   2   16   8.3    4
# 1 ...     1    2    2    2    0    2   1   18  10.1   26
# 2 ...     1    1    2    0    0    2   3   20  15.0   20
# 3 ...     1    2    2    1    0    0   2   17  12.3   16
# 4 ...     0    1    2    1    0    2   2    5   0.5   14
#
# [5 rows x 30 columns]

# %%
df09des=df09[["FG","FT","3P"]]
df09des.describe()
# Out:
#               FG         FT        3P
# count  80.000000  80.000000  80.00000
# mean    5.800000   2.887500   1.81250
# std     2.160638   2.495534   1.42397
# min     0.000000   0.000000   0.00000
# 25%     4.750000   1.000000   1.00000
# 50%     6.000000   3.000000   2.00000
# 75%     7.000000   4.000000   3.00000
# max    10.000000  11.000000   6.00000

# %%
df09.plot(x='FG', y='FT', style='o')  
plt.title('FG vs FT')  
plt.xlabel('FG')  
plt.ylabel('FT')  
plt.show()

# %%
df09.plot(x='FG', y='3P', style='o')  
plt.title('FG vs 3P')  
plt.xlabel('FG')  
plt.ylabel('3P')  
plt.show()

# %%
df09.plot(x='3P', y='FT', style='o')  
plt.title('3P vs FT')  
plt.xlabel('3P')  
plt.ylabel('FT')  
plt.show()

# %%
FG09= df09des.hist(column='FG')
FG09
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1E392F60>]],
#       dtype=object)

# %%
FT09= df09des.hist(column='FT')
FT09
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1E3ED160>]],
#       dtype=object)

# %%
ThreeP09= df09des.hist(column='3P')
ThreeP09
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1E496DD8>]],
#       dtype=object)

# %%
df10 = pd.read_csv(r"C:\Users\Kim Ramos\Desktop\Engma data\Ray Allen\CSV\RayAllen_2010-11.csv", sep=",")
df10.head()
# Out:
#    Rk  G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS        MP  \
# 0   1  1  26 10 2010  35-098  BOS        NaN  MIA     W (+8)   1  39:16:00
# 1   2  2  27 10 2010  35-099  BOS          @  CLE     L (-8)   1  35:26:00
# 2   3  3  29 10 2010  35-101  BOS        NaN  NYK     W (+4)   1  40:27:00
# 3   4  4   2 11 2010  35-105  BOS          @  DET    W (+23)   1  33:43:00
# 4   5  5   3 11 2010  35-106  BOS        NaN  MIL     W (+3)   1  44:58:00
#
#   ...   DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc  +/-
# 0 ...     1    1    1    0    0    1   1   20  13.3   -2
# 1 ...     2    4    4    0    0    1   3   12   6.7   -1
# 2 ...     3    3    2    0    0    3   2   12   4.4   -1
# 3 ...     1    4    3    1    0    1   2   16  12.3   24
# 4 ...     4    6    2    2    0    2   4   23  14.6    9
#
# [5 rows x 30 columns]

# %%
df10des=df10[["FG","FT","3P"]]
df10des.describe()
# Out:
#               FG         FT         3P
# count  80.000000  80.000000  80.000000
# mean    6.000000   2.412500   2.100000
# std     2.386672   1.913931   1.355719
# min     2.000000   0.000000   0.000000
# 25%     4.000000   1.000000   1.000000
# 50%     6.000000   2.000000   2.000000
# 75%     8.000000   3.000000   3.000000
# max    13.000000   8.000000   7.000000

# %%
df10.plot(x='FG', y='FT', style='o')  
plt.title('FG vs FT')  
plt.xlabel('FG')  
plt.ylabel('FT')  
plt.show()

# %%
df10.plot(x='FG', y='3P', style='o')  
plt.title('FG vs 3P')  
plt.xlabel('FG')  
plt.ylabel('3P')  
plt.show()

# %%
df10.plot(x='3P', y='FT', style='o')  
plt.title('3P vs FT')  
plt.xlabel('3P')  
plt.ylabel('FT')  
plt.show()

# %%
df10['3P'].corr(df10['FT'])
# Out:
# -0.06000423721263809

# %%
FG10= df10des.hist(column='FG')
FG10
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1E663F60>]],
#       dtype=object)

# %%
FT10= df10des.hist(column='FT')
FT10
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1EAF93C8>]],
#       dtype=object)

# %%
ThreeP10= df10des.hist(column='3P')
ThreeP10
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020A1E51C470>]],
#       dtype=object)
